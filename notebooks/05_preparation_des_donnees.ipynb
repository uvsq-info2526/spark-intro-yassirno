# %% [markdown]
# # Initialiser Spark

# %%
from pyspark import SparkContext, SparkConf
conf = SparkConf().setAppName("Notebook").setMaster("local")
sc = SparkContext(conf=conf)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/11/10 10:17:16 WARN Utils: Your hostname, Dell, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/11/10 10:17:16 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/10 10:17:16 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/11/10 10:17:17 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/11/10 10:17:17 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %% [markdown]
# # Vérifier le contenu du fichier

# %%
prenoms = sc.textFile("prenoms.txt")
prenoms.takeSample(False, 10)
# Out:
# ['1;CHARLES;2000;39;6',
#  '2;MARIANNE;1966;47;3',
#  '1;HUGUES;1929;79;3',
#  '2;CÉCILIA;1992;91;14',
#  '1;AMINE;2018;90;6',
#  '1;GASPARD;2006;29;9',
#  '2;CLAUDINE;1970;72;10',
#  '2;GARANCE;2002;91;5',
#  '2;AGATHE;1995;61;3',
#  '2;NOËLLE;1946;34;4']

# %% [markdown]
# # Extraire et sauvegarder un échantillon
# 1. Expliquer ce que fait la ligne suivante

# %%
prenoms.filter(lambda l: l.startswith("sexe") == False)\
    .filter(lambda l: "XX" not in l)\
    .sample(False, .001)\
    .saveAsTextFile("prenoms_sample.txt")

# %% [markdown]
# Ce code prend un fichier de prénoms et en crée un petit échantillon. Il enlève d’abord les lignes d’en-tête et celles qui contiennent “XX” puis il choisit au hasard 0,1 % des lignes restantes. Le résultat est enregistré dans un nouveau fichier

# %% [markdown]
# # Vérifier l'échantillon

# %%
echantillon = sc.textFile("prenoms_sample.txt")
print(echantillon.count())
print(echantillon.filter(lambda l: l.startswith("sexe")).count())
print(echantillon.filter(lambda l: "XX" in l).count())
# Out:
# 3892
# 0
# 0
